# %%
import os
import matplotlib.pyplot as plt
from utils import *

shifter_pro = ShifterPro(plt.imread("CORREL/image_0.png"))

images = [plt.imread(f"CORREL/image_1_delta{i:02d}.png") for i in range(1,51)]

# %%
plt.imshow(shifter_pro.image_ref, cmap="Set1")

# %%
print(shifter_pro.predict(images[13],6,10))
# Out:
#       fun: -164804.40202281557
#  hess_inv: array([[-3.05011548,  0.0974994 ],
#        [ 0.0974994 ,  1.08341354]])
#       jac: array([-335.50976562,  144.53125   ])
#   message: 'Desired error not necessarily achieved due to precision loss.'
#      nfev: 348
#       nit: 1
#      njev: 112
#    status: 2
#   success: False
#         x: array([1036.69668884,  134.68474933])
